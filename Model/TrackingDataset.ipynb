# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-64b0d90d-da01-4e66-9417-428548c7c6e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64b0d90d-da01-4e66-9417-428548c7c6e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"hhenry01","key":"b49e2124d4d035ac303ca3eec35f1710"}'}

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d kmader/videoobjecttracking
# Out:
# ...
# 100% 5.82G/5.83G [01:38<00:00, 67.5MB/s]
# 100% 5.83G/5.83G [01:38<00:00, 63.8MB/s]

# %%
# !unzip videoobjecttracking.zip

# %%
import torch, torchvision, PIL, numpy as np
import pathlib
import PIL
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from tqdm.auto import tqdm
import pandas as pd
import os

# %% [markdown]
# First edit the directory structure and take what we need.

# %%
# !mkdir dataset

# %%
data = pd.read_csv('TrackingDataset/BoBot/Vid_A_ball/groundtruth.txt', names=('x','y','w','h'))
data
# Out:
#           x       y      w      h
# 0    200.34  113.73  45.13  45.59
# 1    202.39  113.73  44.68  45.59
# 2    203.30  113.73  44.68  45.13
# 3    203.30  114.19  44.68  44.90
# 4    201.94  114.19  45.35  45.58
# ..      ...     ...    ...    ...
# 597  138.35  162.05  37.83  38.75
# 598  137.21  162.96  38.52  38.98
# 599  137.66  163.42  38.29  38.29
# 600  137.44  163.42  37.83  38.52
# 601  135.38  163.87  38.30  38.30
#
# [602 rows x 4 columns]

# %%
indices = os.listdir('TrackingDataset/BoBot/Vid_A_ball/')
indices.remove("gt.txt")
indices.remove("groundtruth.txt")
indices.sort()
indices

# %%
data.index = indices
data
# Out:
#                   x       y      w      h
# img0002.jpg  200.34  113.73  45.13  45.59
# img0003.jpg  202.39  113.73  44.68  45.59
# img0004.jpg  203.30  113.73  44.68  45.13
# img0005.jpg  203.30  114.19  44.68  44.90
# img0006.jpg  201.94  114.19  45.35  45.58
# ...             ...     ...    ...    ...
# img0599.jpg  138.35  162.05  37.83  38.75
# img0600.jpg  137.21  162.96  38.52  38.98
# img0601.jpg  137.66  163.42  38.29  38.29
# img0602.jpg  137.44  163.42  37.83  38.52
# img0603.jpg  135.38  163.87  38.30  38.30
#
# [602 rows x 4 columns]
